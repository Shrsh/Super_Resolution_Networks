# %%
import matplotlib.pyplot as plt
import pickle

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN
##250 = 27.25 
#0.005 mast
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 136
# Flickr 24.065616206357618   128 : 25.32984822739929    23.100995470077585
# Div2K 24.9632305109974   101 : 26.328613045735846    26.228737136006224
# urban100 26.84597988885988   9 : 27.247581190532067    26.572316972319044

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN
##190 = 26.95 , 26.34
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
# plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 368
# Flickr 20.63836087313934   292 : 24.990134733941936    23.462137809012688
# Div2K 20.43893067394654   167 : 26.641916861887537    25.336290295344757
# urban100 21.631104765744293   277 : 27.129830208197365    25.64080778527631
# Train 17.185698005737102   365 : 24.81041943089363    24.802350422687304

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 100
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
# plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 395
# Flickr 19.999917656132038   355 : 25.436307322200946    24.00639527677532
# Div2K 20.883776470901047   312 : 26.516841270638412    25.341802798491816
# urban100 20.933698042026016   334 : 27.23369692784243    26.297191311698995
# Train 16.306022093420115   394 : 24.82258583614557    24.82258583614557

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = Alternate epoch 
#LR of G = 0.0002
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
# plt.plot(db2,label="Div2K")
# plt.plot(db3,label="256*256")
# plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 404
# Flickr 23.867130764964752   238 : 28.48975004037891    27.1151639632857
# Div2K 21.56622865362501   357 : 26.955285408689996    24.66349643589767
# urban100 22.6075295577137   251 : 27.274531180393822    25.17932008550249
# Train 18.47591176832262   400 : 25.274097227220885    25.221134734878273

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = Alternate epoch 
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 314
# Flickr 23.86988851201972   142 : 28.548930548520218    25.92333614975113
# Div2K 21.471628069290873   134 : 26.81926048810268    24.767156572900888
# urban100 22.465696652499332   248 : 27.4089109141564    25.270848735883643
# Train 18.342450259279566   312 : 25.109906924136617    25.090257584568263

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 100 
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 305
# Flickr 24.087700337993354   232 : 28.452727091023455    27.270075739613763
# Div2K 22.357330073864922   154 : 26.636398235893758    25.84041728607117
# urban100 22.56627199987917   207 : 27.290983249148834    26.537386661328256
# Train 18.131794695208136   295 : 25.06349225316809    25.06157792596128

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.5
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 249
# Flickr 23.323783461132265   229 : 28.35262438442754    27.560317490356656
# Div2K 21.904352558542627   219 : 26.793609095151464    25.767468292472138
# urban100 23.051978798549705   140 : 26.984073094615674    25.710436972279783
# Train 18.186733768747864   247 : 24.954034885315927    24.92138403060324

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.005
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 315
# Flickr 23.547310409190636   221 : 28.36585436759931    27.320794831217864
# Div2K 21.960095796107233   130 : 26.80636987313715    25.568519239040775
# urban100 23.370100409648312   265 : 27.21655543761852    24.903084738338265
# Train 18.590936892361253   309 : 25.06796459238643    25.066605917050143

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.05
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 257
# Flickr 22.553644187943682   239 : 28.526716859717776    25.922034157398677
# Div2K 21.249604239582354   226 : 26.634390356332464    26.30048789120689
# urban100 21.944958879521593   224 : 27.19959832239838    25.777277911450504
# Train 17.613119189943195   256 : 24.98224934656288    24.98224934656288

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#Relativistic Discriminator Loss + Generator Extended Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 362
# Flickr 24.177001166563585   215 : 28.410771267584728    26.197761324623254
# Div2K 22.411588481746737   292 : 26.814229370506418    25.888284734004113
# urban100 22.59239503501349   250 : 27.337491539619123    25.77935744880421
# Train 18.702142136741696   357 : 25.211027691152612    25.199780637567947

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#Relativistic Discriminator Loss + Generator Extended Loss
#Better initialisation and Plateu LR 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 131
# Flickr 22.670517862410588   108 : 27.941518732201096    25.98716554877303
# Div2K 20.651406024334005   129 : 26.28575977327167    24.58473437988804
# urban100 21.220670316902112   78 : 26.86328781438914    26.378671351765625
# Train 16.483464442871348   130 : 24.244372094648835    24.244372094648835

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#Relativistic Discriminator Loss + Generator Extended Loss
#Better initialisation and Plateu LR 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 317
# Flickr 23.843342785901413   286 : 28.498282351259967    26.674807913434975
# Div2K 21.669021841794237   245 : 26.84905675236387    25.747859575057692
# urban100 22.153038535506376   193 : 27.298309649227058    25.28645719806185
# Train 18.395522924940394   316 : 25.10794347084124    25.10794347084124

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#Relativistic Discriminator Loss + Generator Extended Loss + Perceptual 
#Better initialisation and  
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 239
# Flickr 23.107907376519798   150 : 28.052305839915228    27.592110715448115
# Div2K 22.14716917239722   127 : 26.62867624325594    25.217856312857457
# urban100 22.226538742609186   130 : 26.95634286711443    25.561034394802395
# Train 18.35883655213098   235 : 24.76408821119496    24.753340325912035

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#0.01 * Relativistic Discriminator Loss + Perceptual  + 0.02* reconstruction loss
#Better initialisation and  
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 115
# Flickr 22.531037857413267   110 : 27.033805685436818    27.0282639731297
# Div2K 20.535835099550454   109 : 25.301266349642077    24.439550792767925
# urban100 21.222219970940273   96 : 26.007177606537397    25.534709103561156
# Train 17.207078774148666   114 : 23.739279183392803    23.739279183392803

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#0.1 * Relativistic Discriminator Loss + Perceptual  + 0.02* reconstruction loss
#Better initialisation and  
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 45
# Flickr 22.842305808207843   16 : 27.130102692050745    26.95338336483863
# Div2K 21.56536767403138   34 : 25.53090031404958    24.41180686634276
# urban100 22.535660812866332   35 : 25.877465843108087    23.991281163204825
# Train 17.973997347231826   43 : 23.9184097960976    23.90855243135323

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#0.1 * Relativistic Discriminator Loss + Perceptual  + 0.02* reconstruction loss
#Initial training with L1 Loss, then using Perceptual and Adversarial 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 205
# Flickr 23.297792752439438   111 : 28.067707378179264    26.39181850212678
# Div2K 21.44046354049184   110 : 26.6247332502215    25.512582773429706
# urban100 22.070110106641728   114 : 26.857135858997935    25.611143207159795
# Train 17.92675181298548   122 : 24.613380844609484    24.260342028811195

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#0.1 * Relativistic Discriminator Loss + Perceptual  + 0.02* reconstruction loss
#Initial training with L1 Loss, then using Perceptual and Adversarial 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 381
# Flickr 23.297792752439438   111 : 28.067707378179264    26.296990055847573
# Div2K 21.44046354049184   110 : 26.6247332502215    24.79617065474503
# urban100 22.070110106641728   352 : 27.046448811299236    24.96926712414885
# Train 17.92675181298548   122 : 24.613380844609484    24.593475379643607

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 50 
#LR of G = 0.0002
#0.5 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#Initial training with L1 Loss and perceptual and then using adversarial with 0.005, 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 301
# Flickr 23.29555680321839   259 : 28.222070354333354    25.942827831882965
# Div2K 21.160885969229923   123 : 26.499740314816684    25.853705084324087
# urban100 22.38601704874117   292 : 27.128516315536718    25.690557363050136
# Train 17.99276307049119   298 : 24.83880014946752    24.82798568678788

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 50 
#LR of G = 0.0002
#First 50 epochs : 41 : 27.668247430975338    26.62843862843776
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#Initial training with L1 Loss and perceptual and then using adversarial with 0.005, 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 244
# Flickr 22.874041123450848   189 : 28.32556905574546    27.385201179958894
# Div2K 21.962839940466935   204 : 26.630660430023788    24.30605155425748
# urban100 21.813847068652258   144 : 27.182133929301283    25.67302852116324
# Train 18.294888807088878   240 : 24.78294405915674    24.781979189392874

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 147
# Discriminator Loss 1.3935317993164062   0 : 1.3935317993164062    1.17575803399086
# Generator Loss 0.6180284743395327   134 : 0.6818121172723727    0.66889233314074

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 100 
#LR of G = 0.0002
#First 50 epochs : 41 : 27.668247430975338    26.62843862843776
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#Initial training with L1 Loss and perceptual and then using adversarial with 0.005, 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 206
# Flickr 21.143398504996714   157 : 27.81548693994469    27.100266120910934
# Div2K 18.648264228153742   195 : 26.231531343666603    25.421529395714792
# urban100 19.42057263871661   123 : 26.69295055706163    26.090884601595477
# Train 16.1361141675305   203 : 24.298788715605667    24.288222849400118

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 100 
#LR of G = 0.0002
#56 epochs : Flickr 21.29065019140357   55 : 27.085157457421612    27.085157457421612
#0.1 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#Initial training with L1 Loss and perceptual and then using adversarial with 0.005, 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)


path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 323
# Flickr 23.263888663969876   149 : 28.29725436140587    26.931661472582128
# Div2K 22.06150629287677   134 : 26.723742516551606    25.873980081398543
# urban100 22.89624618534265   189 : 27.105812216968225    26.032306578986454
# Train 18.606919138338583   319 : 24.873637949968206    24.862938442832572

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 323
# Discriminator Loss 1.4357450008392334   0 : 1.4357450008392334    1.2011590003967285
# Generator Loss 0.3996942983223842   156 : 0.5528980585244986    0.5420893329570736

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#+0.2 in fake and -.2 in real
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)


path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 152
# Flickr 23.00773580024196   87 : 28.09326556781048    25.50416423521282
# Div2K 21.41691910766946   104 : 26.435865560911385    24.498518579934576
# urban100 22.357039845059834   122 : 26.99391718332145    26.06346755444063
# Train 17.48273500558922   151 : 24.640311719115168    24.640311719115168

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 152
# Discriminator Loss 1.4451406002044678   0 : 1.4451406002044678    1.3841817378997803
# Generator Loss 0.47816078951455887   151 : 0.6612277761843409    0.6612277761843409

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#-.2 in real
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 320
# Flickr 23.479512404828306   177 : 28.42287979681174    26.50264304278345
# Div2K 22.090189046997622   192 : 26.598520859648925    25.139736916315357
# urban100 22.13640995348605   229 : 26.98153386012784    24.867842626067194
# Train 17.96340243241467   319 : 24.84391637619197    24.84391637619197

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 320
# Discriminator Loss 1.562904715538025   0 : 1.562904715538025    1.3870251178741455
# Generator Loss 0.469465646403947   319 : 0.690354633654944    0.690354633654944

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#-.1 in real
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 346
# Flickr 23.72688621893262   245 : 28.475317651277145    25.78959055121594
# Div2K 21.68647060857175   308 : 26.674702467569887    25.890577952099655
# urban100 22.153768078413187   340 : 27.14420886767038    26.184256084054635
# Train 18.078052705006403   341 : 24.908179559336435    24.906302454130124

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 346
# Discriminator Loss 1.501882553100586   0 : 1.501882553100586    1.3872408866882324
# Generator Loss 0.4746606318929077   345 : 0.6871431928414565    0.6871431928414565

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 1 
#LR of G = 0.0002 and beta 1 = 0.5
#LR of D = 0.000005

path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 288
# Flickr 23.174318911802647   204 : 28.169096288137506    26.873921994227793
# Div2K 19.995865373123408   287 : 26.63164916824418    26.63164916824418
# urban100 21.73001055484317   195 : 27.05702954228787    25.871673943674544
# Train 16.64283795242868   285 : 24.59564957715719    24.59097655557452

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 288
# Discriminator Loss 1.452791114286943   0 : 1.452791114286943    1.1082242114977403
# Generator Loss 0.5201706237652722   287 : 0.6927156397120445    0.6927156397120445

# %%
# scale_ratio in RDB = 1
# Kaiming : 0.3 
# Lr_G = 0.0001 (beta_1 = 0.9)
# Only perceptual and L1 loss 

path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 188
# Flickr 22.188491433666087   160 : 28.344315016208753    25.271125469363373
# Div2K 20.07392581919374   143 : 26.471008823304942    24.82842264421037
# urban100 21.42472987521444   156 : 26.956711698288753    25.420102219393414
# Train 16.18621271950499   185 : 24.493226202736558    24.4894863462855

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.4 
# Lr_G = 0.0002 (beta_1 = 0.9)
# Only perceptual and L1 loss 

path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 208
# Flickr 24.33170025230225   121 : 28.351222299148667    25.517300542473738
# Div2K 21.276681200759334   174 : 26.582177029446537    25.37200159085598
# urban100 22.779979252159215   86 : 27.105129736326326    25.167241131418088
# Train 18.054675152053733   204 : 24.701036635370528    24.69802432834578

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.4 
# Lr_G = 0.0002 (beta_1 = 0.9)
# Only perceptual and L1 loss 
# New VGG Loss after relu5_4

path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 139
# Flickr 24.706083030933566   85 : 27.48586525517352    27.085059706239484
# Div2K 23.11360133563027   133 : 25.921334880840266    25.652580896692328
# urban100 23.404468261072836   100 : 26.34007576809166    25.625139109434713
# Train 19.943905954927118   137 : 24.84858738014791    24.844964879087055

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.4 
# Lr_G = 0.0002 (beta_1 = 0.9)
# Only perceptual and L1 loss 
# New VGG Loss before relu5_4
# L1 loss with 0.5 weightage

path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 121
# Flickr 24.761062090043268   78 : 27.297972976912565    27.047240870156667
# Div2K 23.13541574897126   102 : 25.810483124515965    25.457384344676385
# urban100 23.382418748237846   93 : 26.14626746398212    25.419878749612792
# Train 19.5852560926872   119 : 24.657124778535604    24.650924114761914

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.4 
# Lr_G = 0.0002 (beta_1 = 0.9)
# Only perceptual and L1 loss 
# New VGG Loss before relu5_4
# L1 loss
# High(conv5_4) Perceptual Loss 

path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 156
# Flickr 22.767405616650965   76 : 27.287458036936677    25.72926844705346
# Div2K 21.090548808166737   135 : 25.669384141654085    24.362668243940988
# urban100 21.64997841165051   113 : 26.092480976690176    24.35676592149287
# Train 18.612973178730485   155 : 23.76775680208892    23.76775680208892

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.4 
# Lr_G = 0.0002 (beta_1 = 0.9)
# Only perceptual and L1 loss 
# New VGG Loss before relu5_4
# L1 loss
# 0.5 * High(conv5_4) Perceptual Loss 

path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 115
# Flickr 24.66066358194125   77 : 27.33162410998901    25.410408988265868
# Div2K 22.269228782555828   56 : 25.834462189569656    23.995189806540576
# urban100 23.02363292274724   64 : 26.216020511235204    24.867945789878988
# Train 18.43298952693166   113 : 23.959189986421094    23.935985095717925

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.3 
# Lr_G = 0.0002 (beta_1 = 0.9)
# Only perceptual and L1 loss 
# New VGG Loss before relu5_4
#  0.5*L1 + 0.25* Percpt
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 18
# Flickr 22.13249473878961   15 : 26.496277998224937    26.428172574275727
# Div2K 21.31330165457175   14 : 25.08746561052987    24.6795864178433
# urban100 21.247666758164307   8 : 24.81673176943118    23.755066537332944
# Train 17.623179292602718   17 : 23.718543328632332    23.718543328632332

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.3 
# Lr_G = 0.0002 (beta_1 = 0.9)
# Only perceptual and L1 loss 
# New VGG Loss before relu5_4
#  L1 + 0.3* Percpt
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 112
# Flickr 23.64877285915619   60 : 27.688768661837667    25.861696771712648
# Div2K 21.80371816982843   80 : 26.004882014763652    25.281918268783233
# urban100 23.041009299707824   105 : 26.23742816173627    25.891080422703567
# Train 18.449465138480242   104 : 24.18428985158329    24.178416695627895

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.3 
# Lr_G = 0.0002 (beta_1 = 0.9)
# Only perceptual and L1 loss 
# New VGG Loss before conv4_2
#  L1 + 0.3* Percpt(layer = 22)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 254
# Flickr 24.20894697052961   181 : 28.335760386099473    27.394145947693964
# Div2K 22.83749878338549   234 : 26.761377073287424    25.25027772831292
# urban100 23.625369058549815   136 : 27.26155005827772    25.987061385984003
# Train 18.601152180469075   248 : 24.71113674315559    24.709913359546718

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.3 
# Lr_G = 0.0002 (beta_1 = 0.9)
# Only perceptual and L1 loss 
# New VGG Loss before conv4_2
#  L1 + 0.3* Percpt(layer = 17)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 53
# Flickr 23.61722584539761   36 : 27.260591680065993    25.97274288179996
# Div2K 21.475902081243934   39 : 25.772486507669857    24.21068709220645
# urban100 22.64981982406257   38 : 26.208646599469844    24.5029482117712
# Train 18.161718060978224   51 : 24.052854234321487    24.04030787666207

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.3 
# Lr_G = 0.0002 (beta_1 = 0.5)
# Only perceptual and L1 loss 
# New VGG Loss before conv4_2
#  L1 + 0.3* Percpt(layer = 22) + Percpt(36)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 201
# Flickr 23.61722584539761   176 : 27.953989861217984    26.42386103522048
# Div2K 21.475902081243934   124 : 26.305190552049336    25.97098497236841
# urban100 22.64981982406257   194 : 27.0503841115643    25.499277585009995
# Train 18.161718060978224   199 : 24.409726637899016    24.40587920506284

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.3 
# Lr_G = 0.0002 (beta_1 = 0.5)
# Only perceptual and L1 loss 
# New VGG Loss before conv4_2
#  L1 + 0.2* Percpt(layer = 22) + Percpt(36)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 104
# Flickr 21.565904907612286   70 : 27.520008688750536    26.662574452435056
# Div2K 20.477674691481962   52 : 26.143947491685203    25.076639092344134
# urban100 20.403764152922918   79 : 26.789449440929808    24.986882993187663
# Train 17.160184452920458   103 : 24.31021031323969    24.31021031323969

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.3 
# Lr_G = 0.0002 (beta_1 = 0.5)
# Only perceptual and L1 loss 
# New VGG Loss before conv4_2
#  L1 + 0.2* Percpt(layer = 22) + Percpt(36)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 189
# Flickr 23.3042710910672   144 : 28.063109461809333    26.26040564942373
# Div2K 20.85842404799413   168 : 26.53927116989539    24.86002603285559
# urban100 21.460244853608916   65 : 26.981533923702994    26.16054557244248
# Train 17.55697691821564   185 : 24.59004265398706    24.584990635511055

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.3 
# Lr_G = 0.0002 (beta_1 = 0.5)
# Only perceptual and L1 loss 
# New VGG Loss before conv4_2
#  L1 + 0.1* Percpt(layer = 22) + Percpt(36)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 418
# Flickr 23.3042710910672   199 : 28.14961397392937    27.024382685545653
# Div2K 20.85842404799413   293 : 26.649724356230614    26.628408209521833
# urban100 21.460244853608916   264 : 27.16007915417447    25.511613711444895
# Train 17.55697691821564   364 : 24.669472138824734    24.665983923158954

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 419
# Discriminator Loss 0.0   376 : 1.5105674505233764    1.493071268905293
# Generator Loss 0.4623468616699202   418 : 0.4795101910694692    0.4795101910694692

# %%
# scale_ratio in RDB = 0.2
# Kaiming : 0.3 
# Lr_G = 0.0002 (beta_1 = 0.5)
# Only L1 loss 
#  L1
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
