# %%
import matplotlib.pyplot as plt
import pickle

# %%
path = "/home/harsh.shukla/SRCNN/SRSN_results/Train_loss.txt"
dbfile = open(path, 'rb')      
db = pickle.load(dbfile)
plt.plot(db)
plt.title('Loss graph')
plt.ylabel('Loss')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
path = "/home/harsh.shukla/SRCNN/SRSN_results/Test_loss.txt"
dbfile = open(path, 'rb')      
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
##Small SRSN + 3*3conv before upsampling
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
max(db)
# Out:
# 23.85047601993726

# %%
##Small SRSN + L1 +skips
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
max(db)
# Out:
# 24.201867674010668

# %%
##Small SRSN + without skip
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
max(db)
# Out:
# 24.005954602813237

# %%
##Small SRSN + 1 with skip as residual
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 13.577428760637307
# 24.09724848045937

# %%
##Small SRSN + 1 with skip as caoncatenation
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 13.449400165004835
# 24.069321185270987

# %%
##Small SRSN + 1 with skip as caoncatenation with simple normalisation
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 10.73130808372456
# 22.97592640280947

# %%
##Small SRSN + 1 with skip connection  + dim=128
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 13.54028993122868
# 24.148487380390115

# %%
##Small SRSN + 1 with skip connection  + dim=128 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier.
#Batch_size = 32, learning_rate_schedular = reduce on plateu and removed one resnet block.

path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-727f44d9b335> in <module>
#       4
#       5 path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
# ----> 6 dbfile = open(path, 'rb')
#       7 db = pickle.load(dbfile)
#       8 plt.plot(db)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt'

# %%
##Small SRSN + 1 with skip connection  + dim=128 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier.
#Batch_size = 32, learning_rate_schedular = reduce on plateu.
#Data augmentation 

path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 16.06063592407378
# 22.1173530271675

# %%
##Small SRSN + 1 with skip connection  + dim=128 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier (removed one resnet block).
#Batch_size = 32, learning_rate_schedular = reduce on plateu.
#Data augmentation 
#Replaced activations by ELU

path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 15.88772968672426
# 21.967470781989668

# %%
##Small SRSN + 1 with skip connection  + dim=64 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier.
#Batch_size = 32, learning_rate_schedular = reduce on plateu and removed one resnet block.
#lr = 0.00001
# Leaky_Relu 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 7.451869836815163
# 19.308019443670716

# %%
# ESRGAN generator small RRDB = 4
#b_size = 64
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 18.08324066417712
# 23.85077297713191

# %%
#Old GAN Generator with postsampling 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 1.480297190916691
# 19.946220070762106

# %%
#Old GAN Generator with Xavier Initialisation and without normalised input. 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 7.074700464392819
# 23.16925706270478

# %%
#ESR GAN generator with normalised input
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 5.541253437310443
# 7.90232369865361

# %%
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 12.029985502468676
# 15.339620616125567

# %%
## Small SRSN + Feedback Network + WITHOUT SKIP WITHIN feedback+convfv after 4 resnet block 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 18.345800631659483
# 22.784775630384498

# %%
## Small SRSN + Feedback Network + WITH SKIP WITHIN feedback+convv after 4 resnet block 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 17.891561674527804
# 23.427093296818605

# %% [markdown]
# # Big Images

# %%
## Small SRSN + Feedback Network + WITH SKIP WITHIN feedback+with out skip within resnet block + convv after 4 resnet block
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),"     ",max(db))
# Out:
# 149
# 20.747913176002648
# 108       24.688380301354016

# %%
## Small SRSN +skip within resnet block + convv after 4 resnet block
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),"     ",max(db))
# Out:
# 28
# 20.016209836426675
# 22       24.086635374368775

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - default growth channels and input channels.
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),"     ",max(db))
# Out:
# 117
# 20.016209836426675
# 82       24.3044242073723

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - default growth channels and input channels. 
#Kaiming Initialisation 
#All activations set to leaky_relu(negative_slope= 0.2)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 56
# 16.88799929046882
# 54 : 24.238493602765313

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 125
# 16.88799929046882
# 81 : 24.370018251890613

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2 and conv3 layers. 
# 6 RDBs
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))

print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 96
# 15.479168809308497
# 53 : 24.470320487162777

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
# 6 RDBs
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))

print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 14
# 15.263559592685061
# 12 : 22.835444434198653

# %%
## Small SRSN + Feedback Network + WITH SKIP WITHIN feedback+with out skip within resnet block + convv after 4 resnet block
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))

print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 231
# 20.747913176002648
# 181 : 24.694736391523847

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2 layers.
#Concatenation of all rdb output + global residual skip connection
# 6 RDBs
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))

print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-6e783c28a039> in <module>
#       6 # 6 RDBs
#       7 path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
# ----> 8 dbfile = open(path, 'rb')
#       9 db = pickle.load(dbfile)
#      10 plt.plot(db)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt'

# %% [markdown]
# # Less Data big Images

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2 and conv3 layers. 
# 6 RDBs
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 273
# 9.869957782956458
# 272 : 23.55483533501924

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2 and conv3 layers. 
# 6 RDBs
#Augmentation - 1.rotate 2.horizontal_shift
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 182
# 13.554916388410556
# 180 : 23.460001014473576

# %%
#Flickr Data

# %%
## Small SRSN +skip within RDB blocks + convv after 6 RDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
# 6 RDBs
#Flickr 2k data only
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print()
print("Flickr",db1[0],"    ",db1.index(max(db1)),":",max(db1))
print()
print("Div2K",db2[0],"    ",db2.index(max(db2)),":",max(db2))
# Out:
# 40
#
# Flickr 19.657721768128948      38 : 22.36834608931869
#
# Div2K 20.354180021924613      38 : 23.885143347356333

# %%
## Small SRSN +skip within RDB blocks + convv after 6 RDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
# 6 RDBs
#Flickr 2k data only
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 70
# Flickr 18.199309067968766   68 : 22.36581718378655
# Div2K 18.36664524645083   68 : 23.873741460809445
# BSD100 22.58218780562987   68 : 26.501494196151427

# %%
## Small SRSN +skip within RDB blocks + convv after 6 RDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
# 6 RDBs
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k data only
# dilation = 2 in the first two conv layers
# 0.4 scale_ratio
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 88
# Flickr 19.233791814970537   82 : 22.348988340600826
# Div2K 19.59296918514854   82 : 23.836621117216676
# BSD100 22.58935413671375   12 : 22.63089331034003

# %%
## Small SRSN +skip within RDB blocks + convv after 6 RDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
# 6 RDBs
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k data only
#scale ratio = 0.2
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 101
# Flickr 18.19151026066517   100 : 22.41899044738164
# Div2K 18.241875521101363   100 : 23.972055817269727
# BSD100 22.66457580648261   30 : 22.696309434147743

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k data only
#scale ratio = 0.2
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 75
# Flickr 18.69924865262626   71 : 22.39972773769924
# Div2K 19.11846993455863   71 : 23.92839778261188
# BSD100 22.614452612478445   31 : 22.668997623483538

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k and Div2K data only
#scale ratio = 0.2
# Only two data
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 58
# Flickr 18.96733707566259   57 : 22.368652371755303
# Div2K 19.24208835738292   55 : 23.890861776613743
# BSD100 22.48890749091546   17 : 22.648107854526287

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k data only
#scale ratio = 0.2
# Only two data
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 110
# Flickr 18.148730553178492   109 : 22.430493406487674
# Div2K 18.187689823549825   109 : 23.99820359454219
# BSD100 22.673972084589458   30 : 22.710618370709533

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#increased dilation
#Used Huber loss instead of L1
#scale ratio = 0.2
# Old Data
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 479
# Flickr 18.582852916950607   434 : 22.855057196846644
# Div2K 18.856324256727987   447 : 24.690002290256885
# BSD100 23.21707765002655   21 : 23.217291845464164

# %%
## Small SRSN, 2 RRDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1
#scale ratio = 0.2
# Old Data
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 531
# Flickr 16.337992662347766   525 : 22.813908014073373
# Div2K 16.23401299129244   529 : 24.630958676672666
# BSD100 23.140182414354946   13 : 23.14144896598862

# %%
## Small SRSN, 2 RRDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1
#scale ratio = 0.2
# Old Data
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
