# %%
import matplotlib.pyplot as plt
import pickle

# %%
path = "/home/harsh.shukla/SRCNN/SRSN_results/Train_loss.txt"
dbfile = open(path, 'rb')      
db = pickle.load(dbfile)
plt.plot(db)
plt.title('Loss graph')
plt.ylabel('Loss')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
path = "/home/harsh.shukla/SRCNN/SRSN_results/Test_loss.txt"
dbfile = open(path, 'rb')      
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
##Small SRSN + 3*3conv before upsampling
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
max(db)
# Out:
# 23.85047601993726

# %%
##Small SRSN + L1 +skips
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
max(db)
# Out:
# 24.201867674010668

# %%
##Small SRSN + without skip
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
max(db)
# Out:
# 24.005954602813237

# %%
##Small SRSN + 1 with skip as residual
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 13.577428760637307
# 24.09724848045937

# %%
##Small SRSN + 1 with skip as caoncatenation
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 13.449400165004835
# 24.069321185270987

# %%
##Small SRSN + 1 with skip as caoncatenation with simple normalisation
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 10.73130808372456
# 22.97592640280947

# %%
##Small SRSN + 1 with skip connection  + dim=128
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 13.54028993122868
# 24.148487380390115

# %%
##Small SRSN + 1 with skip connection  + dim=128 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier.
#Batch_size = 32, learning_rate_schedular = reduce on plateu and removed one resnet block.

path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-727f44d9b335> in <module>
#       4
#       5 path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
# ----> 6 dbfile = open(path, 'rb')
#       7 db = pickle.load(dbfile)
#       8 plt.plot(db)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt'

# %%
##Small SRSN + 1 with skip connection  + dim=128 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier.
#Batch_size = 32, learning_rate_schedular = reduce on plateu.
#Data augmentation 

path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 16.06063592407378
# 22.1173530271675

# %%
##Small SRSN + 1 with skip connection  + dim=128 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier (removed one resnet block).
#Batch_size = 32, learning_rate_schedular = reduce on plateu.
#Data augmentation 
#Replaced activations by ELU

path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 15.88772968672426
# 21.967470781989668

# %%
##Small SRSN + 1 with skip connection  + dim=64 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier.
#Batch_size = 32, learning_rate_schedular = reduce on plateu and removed one resnet block.
#lr = 0.00001
# Leaky_Relu 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 7.451869836815163
# 19.308019443670716

# %%
# ESRGAN generator small RRDB = 4
#b_size = 64
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 18.08324066417712
# 23.85077297713191

# %%
#Old GAN Generator with postsampling 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 1.480297190916691
# 19.946220070762106

# %%
#Old GAN Generator with Xavier Initialisation and without normalised input. 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 7.074700464392819
# 23.16925706270478

# %%
#ESR GAN generator with normalised input
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 5.541253437310443
# 7.90232369865361

# %%
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 12.029985502468676
# 15.339620616125567

# %%
## Small SRSN + Feedback Network + WITHOUT SKIP WITHIN feedback+convfv after 4 resnet block 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 18.345800631659483
# 22.784775630384498

# %%
## Small SRSN + Feedback Network + WITH SKIP WITHIN feedback+convv after 4 resnet block 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 17.891561674527804
# 23.427093296818605

# %% [markdown]
# # Big Images

# %%
## Small SRSN + Feedback Network + WITH SKIP WITHIN feedback+with out skip within resnet block + convv after 4 resnet block
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),"     ",max(db))
# Out:
# 149
# 20.747913176002648
# 108       24.688380301354016

# %%
## Small SRSN +skip within resnet block + convv after 4 resnet block
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),"     ",max(db))
# Out:
# 28
# 20.016209836426675
# 22       24.086635374368775

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - default growth channels and input channels.
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),"     ",max(db))
# Out:
# 117
# 20.016209836426675
# 82       24.3044242073723

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - default growth channels and input channels. 
#Kaiming Initialisation 
#All activations set to leaky_relu(negative_slope= 0.2)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 56
# 16.88799929046882
# 54 : 24.238493602765313

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 125
# 16.88799929046882
# 81 : 24.370018251890613

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2 and conv3 layers. 
# 6 RDBs
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))

print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 96
# 15.479168809308497
# 53 : 24.470320487162777

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
# 6 RDBs
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))

print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 14
# 15.263559592685061
# 12 : 22.835444434198653

# %%
## Small SRSN + Feedback Network + WITH SKIP WITHIN feedback+with out skip within resnet block + convv after 4 resnet block
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))

print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 231
# 20.747913176002648
# 181 : 24.694736391523847

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2 layers.
#Concatenation of all rdb output + global residual skip connection
# 6 RDBs
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))

print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-6e783c28a039> in <module>
#       6 # 6 RDBs
#       7 path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
# ----> 8 dbfile = open(path, 'rb')
#       9 db = pickle.load(dbfile)
#      10 plt.plot(db)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt'

# %% [markdown]
# # Less Data big Images

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2 and conv3 layers. 
# 6 RDBs
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 273
# 9.869957782956458
# 272 : 23.55483533501924

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2 and conv3 layers. 
# 6 RDBs
#Augmentation - 1.rotate 2.horizontal_shift
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(len(db))
print(db[0])
print(db.index(max(db)),":",max(db))
# Out:
# 182
# 13.554916388410556
# 180 : 23.460001014473576

# %%
#Flickr Data

# %%
## Small SRSN +skip within RDB blocks + convv after 6 RDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
# 6 RDBs
#Flickr 2k data only
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print()
print("Flickr",db1[0],"    ",db1.index(max(db1)),":",max(db1))
print()
print("Div2K",db2[0],"    ",db2.index(max(db2)),":",max(db2))
# Out:
# 40
#
# Flickr 19.657721768128948      38 : 22.36834608931869
#
# Div2K 20.354180021924613      38 : 23.885143347356333

# %%
## Small SRSN +skip within RDB blocks + convv after 6 RDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
# 6 RDBs
#Flickr 2k data only
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 70
# Flickr 18.199309067968766   68 : 22.36581718378655
# Div2K 18.36664524645083   68 : 23.873741460809445
# BSD100 22.58218780562987   68 : 26.501494196151427

# %%
## Small SRSN +skip within RDB blocks + convv after 6 RDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
# 6 RDBs
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k data only
# dilation = 2 in the first two conv layers
# 0.4 scale_ratio
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 88
# Flickr 19.233791814970537   82 : 22.348988340600826
# Div2K 19.59296918514854   82 : 23.836621117216676
# BSD100 22.58935413671375   12 : 22.63089331034003

# %%
## Small SRSN +skip within RDB blocks + convv after 6 RDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
# 6 RDBs
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k data only
#scale ratio = 0.2
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 101
# Flickr 18.19151026066517   100 : 22.41899044738164
# Div2K 18.241875521101363   100 : 23.972055817269727
# BSD100 22.66457580648261   30 : 22.696309434147743

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k data only
#scale ratio = 0.2
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 45
# Flickr 20.906703139536464   42 : 22.74786834293517
# Div2K 21.78603213710591   44 : 24.53782590406236
# BSD100 23.054160502773662   8 : 23.132740959460648

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k and Div2K data only
#scale ratio = 0.2
# Only two data
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 58
# Flickr 18.96733707566259   57 : 22.368652371755303
# Div2K 19.24208835738292   55 : 23.890861776613743
# BSD100 22.48890749091546   17 : 22.648107854526287

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#increased dilation
#Used Huber loss instead of L1
#Flickr 2k data only
#scale ratio = 0.2
# Only two data
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 110
# Flickr 18.148730553178492   109 : 22.430493406487674
# Div2K 18.187689823549825   109 : 23.99820359454219
# BSD100 22.673972084589458   30 : 22.710618370709533

# %%
## Small SRSN +skip within RDB blocks + convv after 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#increased dilation
#Used Huber loss instead of L1
#scale ratio = 0.2
# Old Data
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 479
# Flickr 18.582852916950607   434 : 22.855057196846644
# Div2K 18.856324256727987   447 : 24.690002290256885
# BSD100 23.21707765002655   21 : 23.217291845464164

# %%
## Small SRSN, 2 RRDB Blocks - 32 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1
#scale ratio = 0.2
# Old Data
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 531
# Flickr 16.337992662347766   525 : 22.813908014073373
# Div2K 16.23401299129244   529 : 24.630958676672666
# BSD100 23.140182414354946   13 : 23.14144896598862

# %%
## Small SRSN, 2 RRDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1 and train till it saturates(at PSNR 24.66), then train of l2 loss. 
#scale ratio = 0.2
# Old Data
#BS=48
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1))
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2))
print("BSD100",db3[0]," ",db3.index(max(db3)),":",max(db3))
# Out:
# 932
# Flickr 16.428539301807287   931 : 22.965841645714967
# Div2K 16.267955667975023   928 : 24.794505569455296
# BSD100 23.362282379216936   28 : 23.364586128213443

# %%
## Small SRSN, 2 RRDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1 and train till it saturates(at PSNR 24.66), then train of l2 loss. 
#scale ratio = 0.2
# Old Data
#BS=8
#Content Loss
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 93
# Flickr 20.808028066219837   83 : 22.940771362592628    22.250589372951698
# Div2K 21.72511404260916   85 : 24.829346843747658    23.903726169080276
# urban100 22.711587525740047   3 : 22.86490047360802    22.73472566090735

# %%
## Small SRSN, 2 RRDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1 and train till it saturates(at PSNR 24.66), then train of l2 loss. 
#scale ratio = 0.2
# Old Data
#BS=10
#Content Loss
#wieghtage to reconstruction = 0.4
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 157
# Flickr 20.906703139536464   153 : 23.010060470762532    22.996512220101696
# Div2K 21.78603213710591   153 : 24.854549702292484    24.8366713303569
# urban100 23.44219148407104   1 : 23.4678061969548    23.44650901868252

# %%
## Small SRSN, 4 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1 and train till it saturates(at PSNR 24.66), then train of l2 loss. 
#scale ratio = 0.2
# Old Data
#BS=10
#Content Loss
# perceptual Loss
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 176
# Flickr 20.679129468775564   171 : 23.234138057099397    23.22093018517725
# Div2K 21.64593491106087   171 : 25.078546236870217    25.040123252328023
# urban100 23.680565690965658   0 : 23.680565690965658    23.649841356170658

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1 and train till it saturates(at PSNR 24.66), then train of l2 loss. 
#scale ratio = 0.2
# Old Data
#BS=10
#Content Loss
# perceptual Loss
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="BSD100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))

print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 135
# Flickr 20.461228912166632   134 : 23.37077360530251    23.37077360530251
# Div2K 21.204678222997128   134 : 25.182261352367874    25.182261352367874
# urban100 23.75546021239995   5 : 23.843240808662    23.843240808662

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1 and train till it saturates(at PSNR 24.66), then train of l2 loss. 
#scale ratio = 0.2
# Old Data
#BS=10
#Content Loss
# perceptual Losses - Low features and High features
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 161
# Flickr 20.434167939396918   140 : 24.074327687081976    23.22402507414022
# Div2K 21.246978388938622   126 : 25.592902287420717    25.073297403222696
# urban100 23.44265438646143   108 : 24.014259811313163    23.964688499558854

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1 and train till it saturates(at PSNR 24.66), then train of l2 loss. 
#scale ratio = 0.2
# Old Data
#BS=10
#Content Loss
# perceptual Losses - (0.01)Low features and High features
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 115
# Flickr 21.284956405850114   108 : 23.625825912933713    23.315624090784475
# Div2K 21.617949312194867   93 : 25.52266997987696    25.027998890458502
# urban100 21.280785033161248   111 : 23.83303397323455    23.71660786518477

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#Used Huber loss instead of L1 and train till it saturates(at PSNR 24.66), then train of l2 loss. 
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - (0.01)Low features and High features
#Using PReLU and Kaiming
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 97
# Flickr 21.87948273998397   91 : 23.708645740749414    23.267850625442374
# Div2K 23.232278375095518   79 : 25.341008503455672    24.724593856112023
# urban100 22.046086835746404   90 : 23.77138517900481    23.709833449373086

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#Kaiming
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - 1*36 feature
#Using Leaky_relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 134
# Flickr 20.77731768376264   132 : 23.967329876796548    23.605456707648433
# Div2K 21.965512268332343   87 : 25.776389444828673    25.282963868648455
# urban100 21.42369690645658   124 : 24.012628717527424    23.974106352173013

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - 1*36 feature
#Using Leaky_relu and Kaiming(0.1 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 16
# Flickr 19.877566652779535   15 : 22.549723158772995    22.549723158772995
# Div2K 20.99346825901932   14 : 24.156409469175312    24.149637527511377
# urban100 20.596096099169785   15 : 22.755791615617685    22.755791615617685

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - high(36) and low(0.1)(15) both 
#Using Leaky_relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 143
# Flickr 21.287732998784268   97 : 23.82262358498992    23.31357331778825
# Div2K 21.722612750108617   101 : 25.59493793192896    25.140633324393566
# urban100 21.22201121200725   114 : 23.969113490508107    23.93089741146529

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - high((.3)16) and low(0.25)(5) both 
#Using Leaky_relu and Kaiming(0.3 scaled)
##50 epochs ---24.95
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 41
# Flickr 20.54644643520543   29 : 23.10486369773917    23.103976144257015
# Div2K 21.155505027755012   25 : 24.96726459575823    24.364117240839214
# urban100 20.562286273540984   39 : 23.36311662854467    22.998659319220728

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - high((.1)16) and low(0.1)(5) both 
#Using Leaky_relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 147
# Flickr 20.938267729904155   140 : 23.644472171485393    22.90757987506946
# Div2K 22.201522438657477   95 : 25.422509168053992    25.094735916653534
# urban100 21.543265228386325   134 : 23.909306177126474    23.758104833517972

# %%
## Small SRSN, 6 RDB Blocks - 64 growth channels and input channels. 
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - high((.1)last) and low(0.2)(10) both 
#Using Leaky_relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 133
# Flickr 20.54644643520543   89 : 23.475007355404273    22.912188945342198
# Div2K 21.155505027755012   89 : 25.430129537207232    25.002658043980553
# urban100 20.562286273540984   119 : 23.887769866220296    23.73998642537574

# %%
## Small SRSN, 6 RFB Blocks - 64 with bn and inter_planes = input_planes/4
#All activations set to leaky_relu(negative_slope= 0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - high((.1)last) and low(0.2)(10) both 
#Using relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 22
# Flickr 18.95542180591772   13 : 22.75259376998427    22.193771631183033
# Div2K 19.615844454064547   20 : 23.849409017232993    23.74769807002923
# urban100 19.152162455373922   21 : 22.624874810674118    22.624874810674118

# %%
## Small SRSN, 6 RFB Blocks - 64 interplanes = input_planes/2 instead of 4. ( also without bn)
#All activations set to relu
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - high((.1)last) and low(0.2)(10) both 
#Using relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 80
# Flickr 20.85956081355437   76 : 23.068546938638505    22.945360257560864
# Div2K 21.70932613887718   74 : 24.72452842209603    24.256756968890237
# urban100 21.021752625487686   78 : 22.87113567213193    22.847794882649684

# %%
## Small SRSN, 6 RFB Blocks - 64 interplanes = input_planes instead of 2. ( also without bn)
#All activations set to leaky_relu(0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - high((.1)last) and low(0.2)(10) both 
#Using relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 100
# Flickr 20.35808722748028   91 : 23.244819325372013    23.198137033339123
# Div2K 21.08655376624554   81 : 24.91968311830139    24.435288937790453
# urban100 20.533417591592173   96 : 22.951147437583693    22.940421754833537

# %%
## Small SRSN, 2 RFDenseB Blocks - RDB + RFB combined.  64 interplanes = input_planes instead of 2. ( also without bn)
#All activations set to leaky_relu(0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - high((.1)last) and low(0.2)(10) both 
#Using relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 67
# Flickr 20.537850833345345   57 : 23.004357883817143    22.494305600263914
# Div2K 21.59104981599203   64 : 24.8818299539699    24.094560493293564
# urban100 20.94081249489145   65 : 23.06630988958269    23.019816290356232

# %%
##RDB in parallel with RFB
## Small SRSN, 2 RFDenseB Blocks - RDB + RFB combined.  64 interplanes = input_planes instead of 2. ( also without bn)
#All activations set to leaky_relu(0.2)
#Increased filter size of conv2  
#scale ratio = 0.2
# Old Data
#BS=10
##Content Loss
# perceptual Losses - high((.1)last) and low(0.2)(10) both 
#Using relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 68
# Flickr 20.31239280655102   64 : 23.08647193652149    22.70340932692227
# Div2K 21.46270774909862   62 : 24.799088296231083    24.370208628538037
# urban100 20.793423616291598   66 : 22.953585444525622    22.948658952865543

# %%
##6 RDB 
#Using relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 251
# Flickr 21.184422388801927   246 : 23.671785994949104    23.216937352752986
# Div2K 21.983834106732914   116 : 25.37761893258992    25.159266013004952
# urban100 21.253866996012295   200 : 23.883407006418622    23.741468083307122

# %%
##4 RRDB 
#Using relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 8
# Flickr 20.537850833345345   7 : 21.963870209327425    21.963870209327425
# Div2K 21.59104981599203   5 : 23.536842529231613    23.464029315826078
# urban100 20.94081249489145   7 : 22.341899993235785    22.341899993235785

# %%
##6 RDB in parallel with RFB
##Scale=1 for RDB
##Scale=0.2 for RFB
#Using relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="urban100")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 96
# Flickr 20.537850833345345   70 : 23.075891118102426    22.601889943756714
# Div2K 21.59104981599203   80 : 24.928355821788756    24.362522795732808
# urban100 20.94081249489145   79 : 23.134359771233555    23.11081735708971

# %%
##4 RDB + 2RRDB in parallel with RFB
##192*192
#Using relu and Kaiming(0.3 scaled)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="192*192")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 96
# Flickr 20.5283828833915   71 : 23.838995569702313    23.589544260547104
# Div2K 21.89738862442258   87 : 25.559974415187845    25.313920813344954
# urban100 22.132150716478055   83 : 25.519287277583075    25.28165663591853

# %%
##4 RDB + 2RRDB in parallel with RFB
##192*192
#Using relu and Kaiming(0.3 scaled)
#RF=11 and 7
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="192*192")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 97
# Flickr 20.23032022096565   72 : 23.809900026878378    23.166896052831017
# Div2K 21.113486731331417   83 : 25.671062393030518    25.010861048209513
# urban100 21.610108691378013   75 : 25.77763265515745    25.156651819589108

# %%
##4 RDB + 2RRDB in parallel with RFB
##192*192
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="192*192")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 101
# Flickr 20.35051053504563   93 : 23.758294419291325    23.063695470563715
# Div2K 21.36233138778611   69 : 25.627798685088123    25.35604612446688
# urban100 21.53642753296142   84 : 25.75974845833205    25.42863929952646

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 87
# Flickr 20.510506481809585   80 : 23.810956507798497    23.43629897052213
# Div2K 21.522284646564845   58 : 25.509985859827875    25.3440802148262
# urban100 22.311379511503958   78 : 26.04841656649328    25.631041967038655

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN
##190 = 26.9 , 26.34
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 9
# Flickr 23.76633994662162   5 : 24.735722466129477    24.53699008814768
# Div2K 25.727933886556826   3 : 26.12574079876974    25.917774895661793
# urban100 25.29016132223656   5 : 26.95847215296121    24.576743772205717

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN
##250 = 27.25 
#0.005 mast
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
# Out:
# 136
# Flickr 24.065616206357618   128 : 25.32984822739929    23.100995470077585
# Div2K 24.9632305109974   101 : 26.328613045735846    26.228737136006224
# urban100 26.84597988885988   9 : 27.247581190532067    26.572316972319044

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN
##190 = 26.95 , 26.34
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
# plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 368
# Flickr 20.63836087313934   292 : 24.990134733941936    23.462137809012688
# Div2K 20.43893067394654   167 : 26.641916861887537    25.336290295344757
# urban100 21.631104765744293   277 : 27.129830208197365    25.64080778527631
# Train 17.185698005737102   365 : 24.81041943089363    24.802350422687304

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 100
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
# plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 395
# Flickr 19.999917656132038   355 : 25.436307322200946    24.00639527677532
# Div2K 20.883776470901047   312 : 26.516841270638412    25.341802798491816
# urban100 20.933698042026016   334 : 27.23369692784243    26.297191311698995
# Train 16.306022093420115   394 : 24.82258583614557    24.82258583614557

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = Alternate epoch 
#LR of G = 0.0002
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="Flickr")
# plt.plot(db2,label="Div2K")
# plt.plot(db3,label="256*256")
# plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 404
# Flickr 23.867130764964752   238 : 28.48975004037891    27.1151639632857
# Div2K 21.56622865362501   357 : 26.955285408689996    24.66349643589767
# urban100 22.6075295577137   251 : 27.274531180393822    25.17932008550249
# Train 18.47591176832262   400 : 25.274097227220885    25.221134734878273

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = Alternate epoch 
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 314
# Flickr 23.86988851201972   142 : 28.548930548520218    25.92333614975113
# Div2K 21.471628069290873   134 : 26.81926048810268    24.767156572900888
# urban100 22.465696652499332   248 : 27.4089109141564    25.270848735883643
# Train 18.342450259279566   312 : 25.109906924136617    25.090257584568263

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 100 
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 305
# Flickr 24.087700337993354   232 : 28.452727091023455    27.270075739613763
# Div2K 22.357330073864922   154 : 26.636398235893758    25.84041728607117
# urban100 22.56627199987917   207 : 27.290983249148834    26.537386661328256
# Train 18.131794695208136   295 : 25.06349225316809    25.06157792596128

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.5
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 249
# Flickr 23.323783461132265   229 : 28.35262438442754    27.560317490356656
# Div2K 21.904352558542627   219 : 26.793609095151464    25.767468292472138
# urban100 23.051978798549705   140 : 26.984073094615674    25.710436972279783
# Train 18.186733768747864   247 : 24.954034885315927    24.92138403060324

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.005
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 315
# Flickr 23.547310409190636   221 : 28.36585436759931    27.320794831217864
# Div2K 21.960095796107233   130 : 26.80636987313715    25.568519239040775
# urban100 23.370100409648312   265 : 27.21655543761852    24.903084738338265
# Train 18.590936892361253   309 : 25.06796459238643    25.066605917050143

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.05
#LR of G = 0.0002
#Relativistic Discriminator Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 257
# Flickr 22.553644187943682   239 : 28.526716859717776    25.922034157398677
# Div2K 21.249604239582354   226 : 26.634390356332464    26.30048789120689
# urban100 21.944958879521593   224 : 27.19959832239838    25.777277911450504
# Train 17.613119189943195   256 : 24.98224934656288    24.98224934656288

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#Relativistic Discriminator Loss + Generator Extended Loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 362
# Flickr 24.177001166563585   215 : 28.410771267584728    26.197761324623254
# Div2K 22.411588481746737   292 : 26.814229370506418    25.888284734004113
# urban100 22.59239503501349   250 : 27.337491539619123    25.77935744880421
# Train 18.702142136741696   357 : 25.211027691152612    25.199780637567947

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#Relativistic Discriminator Loss + Generator Extended Loss
#Better initialisation and Plateu LR 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 131
# Flickr 22.670517862410588   108 : 27.941518732201096    25.98716554877303
# Div2K 20.651406024334005   129 : 26.28575977327167    24.58473437988804
# urban100 21.220670316902112   78 : 26.86328781438914    26.378671351765625
# Train 16.483464442871348   130 : 24.244372094648835    24.244372094648835

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#Relativistic Discriminator Loss + Generator Extended Loss
#Better initialisation and Plateu LR 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 317
# Flickr 23.843342785901413   286 : 28.498282351259967    26.674807913434975
# Div2K 21.669021841794237   245 : 26.84905675236387    25.747859575057692
# urban100 22.153038535506376   193 : 27.298309649227058    25.28645719806185
# Train 18.395522924940394   316 : 25.10794347084124    25.10794347084124

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#Relativistic Discriminator Loss + Generator Extended Loss + Perceptual 
#Better initialisation and  
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 239
# Flickr 23.107907376519798   150 : 28.052305839915228    27.592110715448115
# Div2K 22.14716917239722   127 : 26.62867624325594    25.217856312857457
# urban100 22.226538742609186   130 : 26.95634286711443    25.561034394802395
# Train 18.35883655213098   235 : 24.76408821119496    24.753340325912035

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#0.01 * Relativistic Discriminator Loss + Perceptual  + 0.02* reconstruction loss
#Better initialisation and  
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1))
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 115
# Flickr 22.531037857413267   110 : 27.033805685436818    27.0282639731297
# Div2K 20.535835099550454   109 : 25.301266349642077    24.439550792767925
# urban100 21.222219970940273   96 : 26.007177606537397    25.534709103561156
# Train 17.207078774148666   114 : 23.739279183392803    23.739279183392803

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#weightage = 0.01
#LR of G = 0.0002
#0.1 * Relativistic Discriminator Loss + Perceptual  + 0.02* reconstruction loss
#Better initialisation and  
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 45
# Flickr 22.842305808207843   16 : 27.130102692050745    26.95338336483863
# Div2K 21.56536767403138   34 : 25.53090031404958    24.41180686634276
# urban100 22.535660812866332   35 : 25.877465843108087    23.991281163204825
# Train 17.973997347231826   43 : 23.9184097960976    23.90855243135323

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#0.1 * Relativistic Discriminator Loss + Perceptual  + 0.02* reconstruction loss
#Initial training with L1 Loss, then using Perceptual and Adversarial 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 205
# Flickr 23.297792752439438   111 : 28.067707378179264    26.39181850212678
# Div2K 21.44046354049184   110 : 26.6247332502215    25.512582773429706
# urban100 22.070110106641728   114 : 26.857135858997935    25.611143207159795
# Train 17.92675181298548   122 : 24.613380844609484    24.260342028811195

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#0.1 * Relativistic Discriminator Loss + Perceptual  + 0.02* reconstruction loss
#Initial training with L1 Loss, then using Perceptual and Adversarial 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 381
# Flickr 23.297792752439438   111 : 28.067707378179264    26.296990055847573
# Div2K 21.44046354049184   110 : 26.6247332502215    24.79617065474503
# urban100 22.070110106641728   352 : 27.046448811299236    24.96926712414885
# Train 17.92675181298548   122 : 24.613380844609484    24.593475379643607

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 50 
#LR of G = 0.0002
#0.5 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#Initial training with L1 Loss and perceptual and then using adversarial with 0.005, 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 301
# Flickr 23.29555680321839   259 : 28.222070354333354    25.942827831882965
# Div2K 21.160885969229923   123 : 26.499740314816684    25.853705084324087
# urban100 22.38601704874117   292 : 27.128516315536718    25.690557363050136
# Train 17.99276307049119   298 : 24.83880014946752    24.82798568678788

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 50 
#LR of G = 0.0002
#First 50 epochs : 41 : 27.668247430975338    26.62843862843776
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#Initial training with L1 Loss and perceptual and then using adversarial with 0.005, 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 244
# Flickr 22.874041123450848   189 : 28.32556905574546    27.385201179958894
# Div2K 21.962839940466935   204 : 26.630660430023788    24.30605155425748
# urban100 21.813847068652258   144 : 27.182133929301283    25.67302852116324
# Train 18.294888807088878   240 : 24.78294405915674    24.781979189392874

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 147
# Discriminator Loss 1.3935317993164062   0 : 1.3935317993164062    1.17575803399086
# Generator Loss 0.6180284743395327   134 : 0.6818121172723727    0.66889233314074

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 100 
#LR of G = 0.0002
#First 50 epochs : 41 : 27.668247430975338    26.62843862843776
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#Initial training with L1 Loss and perceptual and then using adversarial with 0.005, 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 206
# Flickr 21.143398504996714   157 : 27.81548693994469    27.100266120910934
# Div2K 18.648264228153742   195 : 26.231531343666603    25.421529395714792
# urban100 19.42057263871661   123 : 26.69295055706163    26.090884601595477
# Train 16.1361141675305   203 : 24.298788715605667    24.288222849400118

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 100 
#LR of G = 0.0002
#56 epochs : Flickr 21.29065019140357   55 : 27.085157457421612    27.085157457421612
#0.1 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#Initial training with L1 Loss and perceptual and then using adversarial with 0.005, 
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)


path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 323
# Flickr 23.263888663969876   149 : 28.29725436140587    26.931661472582128
# Div2K 22.06150629287677   134 : 26.723742516551606    25.873980081398543
# urban100 22.89624618534265   189 : 27.105812216968225    26.032306578986454
# Train 18.606919138338583   319 : 24.873637949968206    24.862938442832572

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 323
# Discriminator Loss 1.4357450008392334   0 : 1.4357450008392334    1.2011590003967285
# Generator Loss 0.3996942983223842   156 : 0.5528980585244986    0.5420893329570736

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#+0.2 in fake and -.2 in real
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
#
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)


path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 152
# Flickr 23.00773580024196   87 : 28.09326556781048    25.50416423521282
# Div2K 21.41691910766946   104 : 26.435865560911385    24.498518579934576
# urban100 22.357039845059834   122 : 26.99391718332145    26.06346755444063
# Train 17.48273500558922   151 : 24.640311719115168    24.640311719115168

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 152
# Discriminator Loss 1.4451406002044678   0 : 1.4451406002044678    1.3841817378997803
# Generator Loss 0.47816078951455887   151 : 0.6612277761843409    0.6612277761843409

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#-.2 in real
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 320
# Flickr 23.479512404828306   177 : 28.42287979681174    26.50264304278345
# Div2K 22.090189046997622   192 : 26.598520859648925    25.139736916315357
# urban100 22.13640995348605   229 : 26.98153386012784    24.867842626067194
# Train 17.96340243241467   319 : 24.84391637619197    24.84391637619197

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 320
# Discriminator Loss 1.562904715538025   0 : 1.562904715538025    1.3870251178741455
# Generator Loss 0.469465646403947   319 : 0.690354633654944    0.690354633654944

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 150 
#LR of G = 0.0002
#-.1 in real
#0.01 * Relativistic Discriminator Loss + Perceptual  + reconstruction loss
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 346
# Flickr 23.72688621893262   245 : 28.475317651277145    25.78959055121594
# Div2K 21.68647060857175   308 : 26.674702467569887    25.890577952099655
# urban100 22.153768078413187   340 : 27.14420886767038    26.184256084054635
# Train 18.078052705006403   341 : 24.908179559336435    24.906302454130124

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 346
# Discriminator Loss 1.501882553100586   0 : 1.501882553100586    1.3872408866882324
# Generator Loss 0.4746606318929077   345 : 0.6871431928414565    0.6871431928414565

# %%
##4 RDB + 2RRDB in parallel with RFB
##128*128
#Using relu and Kaiming(0.3 scaled)
#RF=9 and 5
# GAN - K = 1 
#LR of G = 0.0002 and beta 1 = 0.5
#LR of D = 0.000005

path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_flickr.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_div.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/PSNR_bsd.txt"
dbfile = open(path, 'rb')
db3 = pickle.load(dbfile)

path = "/home/harsh.shukla/SRCNN/GAN_results/Train.txt"
dbfile = open(path, 'rb')
db4 = pickle.load(dbfile)
plt.plot(db1,label="400*400")
plt.plot(db2,label="Div2K")
plt.plot(db3,label="256*256")
plt.plot(db4,label="Train")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Flickr",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Div2K",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
print("urban100",db3[0]," ",db3.index(max(db3)),":",max(db3),"  ",db3[-1])
print("Train",db4[0]," ",db4.index(max(db4)),":",max(db4),"  ",db4[-1])
# Out:
# 274
# Flickr 23.174318911802647   204 : 28.169096288137506    25.674291734442868
# Div2K 19.995865373123408   222 : 26.54693950796563    25.498414864584703
# urban100 21.73001055484317   195 : 27.05702954228787    25.008003268800035
# Train 16.64283795242868   271 : 24.58403301816578    24.570668684675002

# %%
path = "/home/harsh.shukla/SRCNN/GAN_results/Discriminator.txt"
dbfile = open(path, 'rb')
db1 = pickle.load(dbfile)
path = "/home/harsh.shukla/SRCNN/GAN_results/Generator_Adversial.txt"
dbfile = open(path, 'rb')
db2 = pickle.load(dbfile)

plt.plot(db1,label="Discriminator Loss")
plt.plot(db2,label="Generator Adv Loss")
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
plt.legend()
print(len(db1)) 
print("Discriminator Loss",db1[0]," ",db1.index(max(db1)),":",max(db1),"  ",db1[-1])
print("Generator Loss",db2[0]," ",db2.index(max(db2)),":",max(db2),"  ",db2[-1])
# Out:
# 274
# Discriminator Loss 1.452791114286943   0 : 1.452791114286943    1.1079124130985953
# Generator Loss 0.5201706237652722   264 : 0.6927010646233192    0.6926982410892641
