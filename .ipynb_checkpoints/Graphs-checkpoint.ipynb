# %%
import matplotlib.pyplot as plt
import pickle

# %%
path = "/home/harsh.shukla/SRCNN/SRSN_results/Train_loss.txt"
dbfile = open(path, 'rb')      
db = pickle.load(dbfile)
plt.plot(db)
plt.title('Loss graph')
plt.ylabel('Loss')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
path = "/home/harsh.shukla/SRCNN/SRSN_results/Test_loss.txt"
dbfile = open(path, 'rb')      
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
##Small SRSN + 3*3conv before upsampling
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
max(db)
# Out:
# 23.85047601993726

# %%
##Small SRSN + L1 +skips
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
max(db)
# Out:
# 24.201867674010668

# %%
##Small SRSN + without skip
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
max(db)
# Out:
# 24.005954602813237

# %%
##Small SRSN + 1 with skip as residual
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 13.577428760637307
# 24.09724848045937

# %%
##Small SRSN + 1 with skip as caoncatenation
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 13.449400165004835
# 24.069321185270987

# %%
##Small SRSN + 1 with skip as caoncatenation with simple normalisation
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 10.73130808372456
# 22.97592640280947

# %%
##Small SRSN + 1 with skip connection  + dim=128
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 13.54028993122868
# 24.148487380390115

# %%
##Small SRSN + 1 with skip connection  + dim=128 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier.
#Batch_size = 32, learning_rate_schedular = reduce on plateu and removed one resnet block.

path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-727f44d9b335> in <module>
#       4
#       5 path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
# ----> 6 dbfile = open(path, 'rb')
#       7 db = pickle.load(dbfile)
#       8 plt.plot(db)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt'

# %%
##Small SRSN + 1 with skip connection  + dim=128 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier.
#Batch_size = 32, learning_rate_schedular = reduce on plateu.
#Data augmentation 

path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 16.06063592407378
# 22.1173530271675

# %%
##Small SRSN + 1 with skip connection  + dim=128 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier (removed one resnet block).
#Batch_size = 32, learning_rate_schedular = reduce on plateu.
#Data augmentation 
#Replaced activations by ELU

path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 15.88772968672426
# 21.967470781989668

# %%
##Small SRSN + 1 with skip connection  + dim=64 + dilation=2(padding values have been changed)
#included conv3 layer which was declared but was not being used earlier.
#Batch_size = 32, learning_rate_schedular = reduce on plateu and removed one resnet block.
#lr = 0.00001
# Leaky_Relu 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 7.451869836815163
# 19.308019443670716

# %%
# ESRGAN generator small RRDB = 4
#b_size = 64
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 18.08324066417712
# 23.85077297713191

# %%
#Old GAN Generator with postsampling 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 1.480297190916691
# 19.946220070762106

# %%
#Old GAN Generator with Xavier Initialisation and without normalised input. 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 7.074700464392819
# 23.16925706270478

# %%
#ESR GAN generator with normalised input
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 5.541253437310443
# 7.90232369865361

# %%
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 12.029985502468676
# 15.339620616125567

# %%
## Small SRSN + Feedback Network + WITHOUT SKIP WITHIN feedback+convfv after 4 resnet block 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 18.345800631659483
# 22.784775630384498

# %%
## Small SRSN + Feedback Network + WITH SKIP WITHIN feedback+convv after 4 resnet block 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 17.891561674527804
# 23.427093296818605

# %%
## Small SRSN + Feedback Network + WITH SKIP WITHIN feedback+convv after 4 resnet block + Big Images 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 20.747913176002648
# 23.702498458786287

# %%
## Small SRSN + Feedback Network + WITH SKIP WITHIN feedback+skip within resnet block + convv after 4 resnet block + Big Images 
path = "/home/harsh.shukla/SRCNN/SRSN_results/PSNR.txt"
dbfile = open(path, 'rb')
db = pickle.load(dbfile)
plt.plot(db)
plt.title('PSNR graph')
plt.ylabel('PSNR')
plt.xlabel('Epochs')
print(db[0])
max(db)
# Out:
# 20.747913176002648
# 23.94109901963857
